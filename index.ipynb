# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
#Your code here
new_columns= [column.lower() for column in df.columns]
new_columns
# Out:
# ['c/a',
#  'unit',
#  'scp',
#  'station',
#  'linename',
#  'division',
#  'date',
#  'time',
#  'desc',
#  'entries',
#  'exits                                                               ']

# %% [markdown]
# # Change the Index to be the Line Names

# %%
#Your code here
df.set_index= ('LINENAME')
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Painstakingly change the index back

# %%
# Your code here
df.reset_index()
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
# Your code here
df['Num_Lines'] = df.LINENAME.map(lambda x: (len(x)))
df.tail()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
#
#             TIME     DESC  ENTRIES  \
# 197620  05:00:00  REGULAR     5554
# 197621  09:00:00  REGULAR     5554
# 197622  13:00:00  REGULAR     5554
# 197623  17:00:00  REGULAR     5554
# 197624  21:00:00  REGULAR     5554
#
#         EXITS                                                                 \
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
#         Num_Lines
# 197620          1
# 197621          1
# 197622          1
# 197623          1
# 197624          1

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = col_name.strip()#Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS', 'Num_Lines'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
#Your code here
df.Date= pd.to_datetime(df.DATE)
df['DAy_of_Week'] =df.Date.dt.dayofweek

# %%
imp
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0   A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  20:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  08/26/2018  00:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  08/26/2018  04:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  08/26/2018  08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  08/26/2018  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/26/2018  16:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/26/2018  20:00:00
# 12  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/27/2018  00:00:00
# 13  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/27/2018  04:00:00
# 14  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/27/2018  08:00:00
# 15  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/27/2018  12:00:00
# 16  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/27/2018  16:00:00
# 17  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/27/2018  20:00:00
# 18  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/28/2018  00:00:00
# 19  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/28/2018  04:00:00
# 20  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/28/2018  08:00:00
# 21  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/28/2018  12:00:00
# 22  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/28/2018  16:00:00
# 23  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/28/2018  20:00:00
# 24  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/29/2018  00:00:00
# 25  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/29/2018  04:00:00
# 26  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/29/2018  08:00:00
# 27  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/29/2018  12:00:00
# 28  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/29/2018  16:00:00
# 29  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/29/2018  20:00:00
# ..   ...   ...       ...     ...      ...      ...         ...       ...
# 70  A002  R051  02-00-01   59 ST  NQR456W      BMT  08/29/2018  16:00:00
# 71  A002  R051  02-00-01   59 ST  NQR456W      BMT  08/29/2018  20:00:00
# 72  A002  R051  02-00-01   59 ST  NQR456W      BMT  08/30/2018  00:00:00
# 73  A002  R051  02-00-01   59 ST  NQR456W      BMT  08/30/2018  04:00:00
# 74  A002  R051  02-00-01   59 ST  NQR456W      BMT  08/30/2018  08:00:00
# 75  A002  R051  02-00-01   59 ST  NQR456W      BMT  08/30/2018  12:00:00
# 76  A002  R051  02-00-01   59 ST  NQR456W      BMT  08/30/2018  16:00:00
# 77  A002  R051  02-00-01   59 ST  NQR456W      BMT  08/30/2018  20:00:00
# 78  A002  R051  02-00-01   59 ST  NQR456W      BMT  08/31/2018  00:00:00
# 79  A002  R051  02-00-01   59 ST  NQR456W      BMT  08/31/2018  04:00:00
# 80  A002  R051  02-00-01   59 ST  NQR456W      BMT  08/31/2018  08:00:00
# 81  A002  R051  02-00-01   59 ST  NQR456W      BMT  08/31/2018  12:00:00
# 82  A002  R051  02-00-01   59 ST  NQR456W      BMT  08/31/2018  16:00:00
# 83  A002  R051  02-00-01   59 ST  NQR456W      BMT  08/31/2018  20:00:00
# 84  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 85  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 86  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 87  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 88  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
# 89  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/25/2018  20:00:00
# 90  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/26/2018  00:00:00
# 91  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/26/2018  04:00:00
# 92  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/26/2018  08:00:00
# 93  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/26/2018  12:00:00
# 94  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/26/2018  16:00:00
# 95  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/26/2018  20:00:00
# 96  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/27/2018  00:00:00
# 97  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/27/2018  04:00:00
# 98  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/27/2018  08:00:00
# 99  A002  R051  02-03-00   59 ST  NQR456W      BMT  08/27/2018  12:00:00
#
#        DESC  ENTRIES    EXITS  Num_Lines  DAy_of_Week
# 0   REGULAR  6736067  2283184          7            5
# 1   REGULAR  6736087  2283188          7            5
# 2   REGULAR  6736105  2283229          7            5
# 3   REGULAR  6736180  2283314          7            5
# 4   REGULAR  6736349  2283384          7            5
# 5   REGULAR  6736562  2283425          7            5
# 6   REGULAR  6736683  2283460          7            6
# 7   REGULAR  6736696  2283461          7            6
# 8   REGULAR  6736705  2283483          7            6
# 9   REGULAR  6736746  2283524          7            6
# 10  REGULAR  6736873  2283587          7            6
# 11  REGULAR  6737067  2283631          7            6
# 12  REGULAR  6737136  2283656          7            0
# 13  REGULAR  6737146  2283658          7            0
# 14  REGULAR  6737169  2283736          7            0
# 15  REGULAR  6737301  2283965          7            0
# 16  REGULAR  6737553  2284025          7            0
# 17  REGULAR  6738257  2284091          7            0
# 18  REGULAR  6738430  2284121          7            1
# 19  REGULAR  6738442  2284126          7            1
# 20  REGULAR  6738474  2284216          7            1
# 21  REGULAR  6738621  2284402          7            1
# 22  REGULAR  6738886  2284425          7            1
# 23  REGULAR  6739630  2284478          7            1
# 24  REGULAR  6739804  2284508          7            2
# 25  REGULAR  6739812  2284512          7            2
# 26  REGULAR  6739847  2284600          7            2
# 27  REGULAR  6739986  2284838          7            2
# 28  REGULAR  6740257  2284896          7            2
# 29  REGULAR  6740888  2284941          7            2
# ..      ...      ...      ...        ...          ...
# 70  REGULAR  6030153  1350380          7            2
# 71  REGULAR  6030668  1350412          7            2
# 72  REGULAR  6030805  1350437          7            3
# 73  REGULAR  6030817  1350440          7            3
# 74  REGULAR  6030844  1350470          7            3
# 75  REGULAR  6030966  1350574          7            3
# 76  REGULAR  6031173  1350626          7            3
# 77  REGULAR  6031651  1350665          7            3
# 78  REGULAR  6031784  1350682          7            4
# 79  REGULAR  6031791  1350685          7            4
# 80  REGULAR  6031821  1350727          7            4
# 81  REGULAR  6031937  1350822          7            4
# 82  REGULAR  6032263  1350887          7            4
# 83  REGULAR  6032656  1350935          7            4
# 84  REGULAR  1117813  4176607          7            5
# 85  REGULAR  1117818  4176631          7            5
# 86  REGULAR  1117821  4176676          7            5
# 87  REGULAR  1117862  4176842          7            5
# 88  REGULAR  1117934  4177054          7            5
# 89  REGULAR  1118003  4177278          7            5
# 90  REGULAR  1118074  4177382          7            6
# 91  REGULAR  1118079  4177391          7            6
# 92  REGULAR  1118084  4177421          7            6
# 93  REGULAR  1118106  4177549          7            6
# 94  REGULAR  1118178  4177733          7            6
# 95  REGULAR  1118244  4177924          7            6
# 96  REGULAR  1118285  4178021          7            0
# 97  REGULAR  1118286  4178025          7            0
# 98  REGULAR  1118295  4178194          7            0
# 99  REGULAR  1118355  4178730          7            0
#
# [100 rows x 13 columns]

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
#Your code here

# %% [markdown]
# # Drop a couple of columns

# %%
# Your code here
